# %%
import pandas as pd

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/sukeshpabba/Python-For-DataScience-Machine-Learning-Bootcamp-Udemy/master/Python-for-Data-Visualization/Pandas%20Built-in%20Data%20Viz/df1"
s=requests.get(url).content
df1=pd.read_csv(io.StringIO(s.decode('utf-8')), index_col = 0)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/sukeshpabba/Python-For-DataScience-Machine-Learning-Bootcamp-Udemy/master/Python-for-Data-Visualization/Pandas%20Built-in%20Data%20Viz/df2"
s=requests.get(url).content
df2=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/sukeshpabba/Python-For-DataScience-Machine-Learning-Bootcamp-Udemy/master/Python-for-Data-Visualization/Pandas%20Built-in%20Data%20Viz/df3"
s=requests.get(url).content
df3=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
# %matplotlib inline
import seaborn as sns

# %%
 df1['A'].hist(bins = 30)
sns.set_style('darkgrid')

# %%
df1['B'].plot(kind = 'hist', bins = 30)

# %%
df1['A'].plot.hist(bins = 30)

# %%
df2.head(2)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680

# %%
df2.plot.area(alpha = 0.4)

# %%
df2.plot.bar(stacked = True)

# %%
df = df1.head(5)

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C']*100)

# %%
df2.plot.box()

# %%
import numpy as np

# %%
np.random.randn(1000,2)
# Out:
# array([[-3.87143393,  0.51389614],
#        [-1.03326584, -0.86387023],
#        [-0.13886893, -0.53914082],
#        ...,
#        [ 0.8888003 ,  0.04812486],
#        [-0.29298617, -0.94730768],
#        [ 0.87756952,  0.86661143]])

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['a', 'b'])

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 45, cmap = 'coolwarm')

# %%
 df2.plot.kde()

# %%
#PANDAS DATA VISUALIZATION EXERCISE

# %%
df3 = pd.DataFrame(np.random.rand(500,4), index = np.arange(0,500), columns = ['a','b','c','d'])

# %%
df3
# Out:
#             a         b         c         d
# 0    0.415939  0.233209  0.789775  0.455194
# 1    0.550551  0.362680  0.110447  0.045601
# 2    0.186396  0.386867  0.180241  0.192276
# 3    0.418095  0.497938  0.640577  0.488823
# 4    0.535776  0.641822  0.341368  0.651226
# ..        ...       ...       ...       ...
# 495  0.626954  0.270199  0.968912  0.283415
# 496  0.990708  0.246490  0.241629  0.094761
# 497  0.101744  0.289199  0.457317  0.048563
# 498  0.563262  0.846626  0.468332  0.670350
# 499  0.987199  0.656905  0.076366  0.560573
#
# [500 rows x 4 columns]

# %%
df3.plot.scatter(x = 'a', y = 'b', c = 'brown', figsize = (12,4))

# %%
df3['a'].plot.hist()

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(alpha = 0.5, bins = 25)

# %%
df3.plot.box(x = 'b', y = 'a')

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.kde(color = 'k', lw = 5, ls = '--')

# %%
df4 = df3.iloc[0:31]

# %%
df4
# Out:
#            a         b         c         d
# 0   0.415939  0.233209  0.789775  0.455194
# 1   0.550551  0.362680  0.110447  0.045601
# 2   0.186396  0.386867  0.180241  0.192276
# 3   0.418095  0.497938  0.640577  0.488823
# 4   0.535776  0.641822  0.341368  0.651226
# 5   0.542044  0.671666  0.154404  0.853835
# 6   0.651166  0.093612  0.330607  0.075213
# 7   0.545306  0.183571  0.786535  0.421053
# 8   0.357245  0.714174  0.343366  0.755392
# 9   0.088528  0.464005  0.989327  0.619633
# 10  0.787022  0.212464  0.107450  0.276979
# 11  0.318820  0.655571  0.634844  0.078245
# 12  0.035473  0.213566  0.288137  0.582108
# 13  0.380207  0.433355  0.148109  0.997258
# 14  0.683918  0.197682  0.064573  0.290183
# 15  0.667207  0.786723  0.259616  0.806683
# 16  0.983420  0.211543  0.761754  0.455880
# 17  0.350745  0.087931  0.611035  0.321800
# 18  0.546756  0.255553  0.854933  0.989280
# 19  0.906509  0.885631  0.130142  0.682302
# 20  0.297435  0.757273  0.508445  0.224980
# 21  0.305702  0.647248  0.790146  0.275376
# 22  0.557976  0.294655  0.985782  0.519651
# 23  0.046001  0.016650  0.216229  0.026455
# 24  0.890409  0.706291  0.970941  0.316399
# 25  0.177680  0.495826  0.245721  0.683420
# 26  0.525718  0.118521  0.514155  0.454303
# 27  0.911371  0.414776  0.616731  0.844964
# 28  0.866079  0.879538  0.897514  0.701595
# 29  0.664349  0.937323  0.146458  0.973059
# 30  0.212592  0.992335  0.964547  0.642818

# %%
df4.plot.area(alpha = 0.4)

# %%
df4.plot.area(alpha = 0.4)
plt.legend (loc = 1)
