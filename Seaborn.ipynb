# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dist = sns.distplot(tips['total_bill'], kde = False, bins = 40)

# %%
fig = sns.jointplot(x='total_bill' , y='tip', data = tips, kind = 'kde')

# %%
fig.savefig('Joint Plot.png', dpi = 200)

# %%
fff = sns.pairplot(tips, hue = 'sex', palette = 'coolwarm')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
fff.savefig('Pair Plot.jpg', dpi = 1000)

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
sns.kdeplot(tips['total_bill'])

# %%
#LECTURE2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['size']
y = tips['total_bill']

plt.bar(x,y)
# Out:
# <BarContainer object of 244 artists>

# %%
import numpy as np
import pandas as pd

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips,
           estimator = np.std)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips,
           estimator = np.sum)

# %%
tips[tips['sex'] == 'Male'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 1 to 242
# Data columns (total 7 columns):
# total_bill    157 non-null float64
# tip           157 non-null float64
# sex           157 non-null category
# smoker        157 non-null category
# day           157 non-null category
# time          157 non-null category
# size          157 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 6.0 KB

# %%
sns.countplot(x = 'sex', data = tips)

# %%
sns.boxplot(x = 'day',y = 'total_bill', data = tips)

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True, hue = 'sex', dodge = True)

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'k')

# %%
sns.factorplot(x = 'day', y = 'total_bill', data = tips, kind = 'box')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill'], kde = False, bins = 40)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde', color = 'c')

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'])

# %%
sns.kdeplot(tips['total_bill'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x= 'sex', y= 'total_bill', data= tips,
            estimator =  np.var)

# %%
sns.countplot(x = 'sex', data = tips)

# %%
sns.boxplot(x = 'day',y = 'total_bill', data = tips)

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True, gridsize = 100000)

# %%
 sns.stripplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True)
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'k')

# %%
sns.factorplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm')

# %%
#MATRIX PLOTS

# %%
flights = sns.load_dataset('flights')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
flights.head(2)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118

# %%
tc = tips.corr()

# %%
sns.heatmap(tc, annot = True, cmap = 'coolwarm')

# %%
fp = flights.pivot_table(index = 'month', columns = 'year',
                    values = 'passengers')

# %%
sns.heatmap(fp)

# %%
sns.clustermap(fp, cmap = 'coolwarm', standard_scale = 1)

# %%
#GRIDS

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
fig.savefig('Iris Pair Plot.jpg', dpi = 500)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
h = sns.FacetGrid(data = tips, col = 'time', row ='smoker')
h.map(sns.distplot, 'total_bill')

# %%
#REGRESSION PLOTS

# %%
sns.lmplot(x='total_bill', y='tip', data = tips, hue = 'sex', markers = ['x', 'v'],
          scatter_kws = {'s':100})

# %%
sns.lmplot(x='total_bill', y='tip', data = tips, 
           col = 'sex', row = 'time')
plt.tight_layout()

# %%
struc = sns.lmplot(x = 'tip', y = 'total_bill', data = tips, hue = 'sex', col = 'day', row = 'time')

# %%
struc.savefig('Regression Plot.jpg', dpi = 1000)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
y = tips[tips['day']=='Thur']['time']

# %%
y.unique()
# Out:
# [Lunch, Dinner]
# Categories (2, object): [Lunch, Dinner]

# %%
tips.iloc[243]
# Out:
# total_bill     18.78
# tip                3
# sex           Female
# smoker            No
# day             Thur
# time          Dinner
# size               2
# Name: 243, dtype: object

# %%
#SEABORN STYLE AND COLOR

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x = 'sex', data = tips)

# %%
sns.set_context('notebook', font_scale = 1.2)

sns.barplot(x= 'sex', y = 'total_bill', data = tips,palette = 'autumn')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex',
          palette = 'winter')

# %%
#SEABORN EXERCISES

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_style('whitegrid')

# %%
sns.jointplot(x = 'fare', y = 'age', data = titanic)

# %%
sns.distplot(titanic['fare'], kde = False, bins = 30, color = 'r')

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
sns.boxplot(x = 'class', y = 'age', data = titanic)

# %%
sns.swarmplot(x = 'class', y = 'age', data = titanic)

# %%
sns.countplot(x = 'sex', data = titanic)

# %%
tcorr = titanic.corr()

# %%
sns.heatmap(tcorr, cmap = 'coolwarm')

# %%
d = sns.FacetGrid(data = titanic, col = 'sex')
d.map(plt.hist, 'age')
plt.figure(figsize=(20,6))

# %%
sns.get_dataset_names()
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
planets = sns.load_dataset('planets')

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
carcrashes = sns.load_dataset('car_crashes')

# %%
carcrashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.distplot(planets['year'], kde = False, bins = 40, rug = True)

# %%
planets.head(1)
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1           269.3   7.1      77.4  2006

# %%
sns.jointplot(x = 'year', y = 'mass', data = planets)

# %%
sns.pairplot(planets)
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\OWNER\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.kdeplot(planets['year'])

# %%
sns.rugplot(planets['year'])

# %%
sns.set_style('darkgrid')

# %%
carcrashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.barplot(x='speeding', y='speeding', data = carcrashes)

# %%
carcrashes['abbrev'].unique().size
# Out:
# 51

# %%
sns.boxplot(x = 'abbrev', y = 'alcohol', data = carcrashes)
sns.set_context('notebook', font_scale = 1)

# %%
sns.factorplot(x='abbrev', y = 'alcohol', data = carcrashes, kind = 'violin')
# Out:
# C:\Users\OWNER\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
carcrashes.head(2)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK

# %%
carcor = carcrashes.corr()

# %%
sns.heatmap(carcor, cmap = 'coolwarm', lw = 1, linecolor = 'w')

# %%
import pandas as pd

# %%
stream = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')

# %%
stream.head(3)
# Out:
#    Unnamed: 0  ID                   Title  Year  Age  IMDb Rotten Tomatoes  \
# 0           0   1               Inception  2010  13+   8.8             87%
# 1           1   2              The Matrix  1999  18+   8.7             87%
# 2           2   3  Avengers: Infinity War  2018  13+   8.5             84%
#
#    Netflix  Hulu  Prime Video  Disney+  Type                       Directors  \
# 0        1     0            0        0     0               Christopher Nolan
# 1        1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0     0         Anthony Russo,Joe Russo
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# ...

# %%
gens = stream ['Genres']

# %%
stream.pivot_table()
# Out:
# 0        Action,Adventure,Sci-Fi,Thriller
# 1                           Action,Sci-Fi
# 2                 Action,Adventure,Sci-Fi
# 3                 Adventure,Comedy,Sci-Fi
# 4                                 Western
#                        ...
# 16739        Comedy,Family,Fantasy,Horror
# 16740                Comedy,Family,Sci-Fi
# 16741                         Documentary
# 16742                         Documentary
# 16743            Documentary,Short,Family
# Name: Genres, Length: 16744, dtype: object

# %%
sns.pairplot(stream)

# %%
stream [stream ['Language'] == 'English'].count()
# Out:
# Unnamed: 0         10955
# ID                 10955
# Title              10955
# Year               10955
# Age                 5122
# IMDb               10713
# Rotten Tomatoes     3300
# Netflix            10955
# Hulu               10955
# Prime Video        10955
# Disney+            10955
# Type               10955
# Directors          10628
# Genres             10934
# Country            10911
# Language           10955
# Runtime            10799
# dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.set_style('darkgrid')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x = 'fare', y = 'age', data = titanic)

# %%
sns.distplot(titanic['fare'], kde = False, bins = 30)

# %%
sns.boxplot(x = 'class', y = 'age', data = titanic)

# %%
sns.countplot(x = 'sex', data = titanic, palette = 'coolwarm')

# %%
tut = titanic.corr()

# %%
sns.heatmap(tut, cmap = 'coolwarm')
plt.title('Titanic Correlation Heatmap'))
# Out:
# Text(0.5, 12.5, 'age')

# %%
a = sns.FacetGrid(data = titanic, col = 'sex')
a.map(plt.hist, 'age')

# %%
stream.head(3)
# Out:
#    Unnamed: 0  ID                   Title  Year  Age  IMDb Rotten Tomatoes  \
# 0           0   1               Inception  2010  13+   8.8             87%
# 1           1   2              The Matrix  1999  18+   8.7             87%
# 2           2   3  Avengers: Infinity War  2018  13+   8.5             84%
#
#    Netflix  Hulu  Prime Video  Disney+  Type                       Directors  \
# 0        1     0            0        0     0               Christopher Nolan
# 1        1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0     0         Anthony Russo,Joe Russo
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# ...

# %%
strcorr = stream.corr()

# %%
sns.heatmap(strcorr, cmap = 'coolwarm', lw = 1 )
